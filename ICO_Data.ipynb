# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
total_prod_csv = Path('C:\\Users\\grego\\Desktop\\GroupProjects\\emergingmarkets\\TotalProduction.csv')
total_prod = pd.read_csv(total_prod_csv, index_col="Crop year").T
exports_csv = Path('C:\\Users\\grego\\Desktop\\GroupProjects\\emergingmarkets\\Exports.csv')
exports = pd.read_csv(exports_csv, index_col="Crop year").T
opening_stx_csv = Path('C:\\Users\\grego\\Desktop\\GroupProjects\\emergingmarkets\\OpeningStocks.csv')
opening_stx = pd.read_csv(opening_stx_csv, index_col="Crop years").T
prices_to_growers_csv = Path('C:\\Users\\grego\\Desktop\\GroupProjects\\emergingmarkets\\PricesToGrowers.csv')
prices_to_growers = pd.read_csv(prices_to_growers_csv)
retail_prices_csv = Path('C:\\Users\\grego\\Desktop\\GroupProjects\\emergingmarkets\\RetailPrices.csv')
retail_prices = pd.read_csv(retail_prices_csv, index_col="Calendar years").T

# %%
exports
# Out:
# Crop year Angola Bolivia (Plurinational State of)  Brazil Burundi Ecuador  \
# 1990/91       79                              112  17,863     412   1,628
# 1991/92       74                               83  21,808     762   1,472
# 1992/93       68                              101  16,752     672   1,288
# 1993/94       28                               37  18,761     353   1,589
# 1994/95       12                               86  15,958     580   2,156
# 1995/96       48                              110  13,760     464   1,438
# 1996/97       51                              105  17,260     186   1,513
# 1997/98       54                              109  15,352     546   1,111
# 1998/99       55                              101  21,085     392     966
# 1999/00       40                              123  21,186     438     983
# 2000/01       20                              113  18,577     407     702
# 2001/02       11                               64  23,767     217     713
# ...
